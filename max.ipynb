# %% [markdown]
# <a href="https://colab.research.google.com/github/elsoncrasta/phytest/blob/main/max.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = []
n=int(input(" enter the no of number to input"))
for I in range(n):
    num=int(input("Enter the number"))
    arr.append(num)
arr.sort()
print(f"""Array;{arr}
sum: {sum(arr)}
avg{sum(arr)/len(arr)}
max: {max(arr)}
 min: {min(arr)}
2 nd highest: {arr[-2]}
2 nd lowest: { arr[1]}
""")
# Out:
#  enter the no of number to input5
# Enter the number2
# Enter the number5
# Enter the number7
# Enter the number9
# Enter the number1
# Array;[1, 2, 5, 7, 9]
# sum: 24
# avg4.8
# max: 9
#  min: 1
# 2 nd highest: 7
# 2 nd lowest: 2
